# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (2.3.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
new_array = np.random.randint(1, 100, 20)

# %%
new_array
# Out:
# array([16, 92, 48, 35, 76, 57, 59, 29, 49, 62, 85, 41, 46, 96, 64, 52, 76,
#        28, 94, 76], dtype=int32)

# %%
new_array > 20
# Out:
# array([False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
new_array[new_array > 20]
# Out:
# array([92, 48, 35, 76, 57, 59, 29, 49, 62, 85, 41, 46, 96, 64, 52, 76, 28,
#        94, 76], dtype=int32)

# %%
matrix_array = np.array([[5, 10, 20], [25, 30, 35], [40, 45, 50]])

# %%
matrix_array
# Out:
# array([[ 5, 10, 20],
#        [25, 30, 35],
#        [40, 45, 50]])

# %%
matrix_array.transpose()
# Out:
# array([[ 5, 25, 40],
#        [10, 30, 45],
#        [20, 35, 50]])

# %%
random_array = np.random.random((6, 1))

# %%
random_array
# Out:
# array([[0.94258513],
#        [0.64498311],
#        [0.36065033],
#        [0.13740086],
#        [0.50008072],
#        [0.2289174 ]])

# %%
random_array.reshape(2,3)
# Out:
# array([[0.94258513, 0.64498311, 0.36065033],
#        [0.13740086, 0.50008072, 0.2289174 ]])
