# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (2.3.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
my_list = [1, 2, 3, 4, 5, 6]

# %%
type(my_list)
# Out:
# list

# %%
np.array(my_list)
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
my_numpy_array = np.array(my_list)

# %%
my_numpy_array.max()
# Out:
# np.int64(6)

# %%
my_list1 = [7, 8, 9, 10 ]

# %%
my_list2 = [1, 2, 3, 4]

# %%
my_list1 + my_list2
# Out:
# [7, 8, 9, 10, 1, 2, 3, 4]

# %%
my_numpy_array1 = np.array(my_list1)

# %%
my_numpy_array2 = np.array(my_list2)

# %%
my_numpy_array1 + my_numpy_array2
# Out:
# array([ 8, 10, 12, 14])

# %%
other_array = np.array([1, 2, 3, 4, 5])

# %%
other_array.sum()
# Out:
# np.int64(15)

# %%
other_array.min()
# Out:
# np.int64(1)

# %%
np.random.randn(4, 4)
# Out:
# array([[ 0.80882178,  0.71818208, -1.00828852,  0.28900279],
#        [-0.21795679,  0.11330015, -0.19519789,  1.23546631],
#        [ 1.10247225, -0.19860589,  0.14995758,  1.32190677],
#        [-0.36162856, -0.64314669, -0.92147246,  0.15283586]])

# %%
np.random.randint(4, 100, 6)
# Out:
# array([52, 74, 15, 79, 63, 37], dtype=int32)
