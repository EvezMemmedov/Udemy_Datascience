# %%
import numpy as np

# %%
my_matrix = [[5, 10], [15, 20]]

# %%
my_matrix[0]
# Out:
# [5, 10]

# %%
my_matrix[0][1]
# Out:
# 10

# %%
numpy_matrix = np.array([[5, 10], [15, 20]])

# %%
numpy_matrix
# Out:
# array([[ 5, 10],
#        [15, 20]])

# %%
numpy_matrix[1][0]
# Out:
# np.int64(15)

# %%
numpy_matrix.sum()
# Out:
# np.int64(50)

# %%
np.ones((4,2))
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.],
#        [1., 1.]])

# %%
np.random.random((4, 5))
# Out:
# array([[0.54454145, 0.54709638, 0.24714508, 0.5168757 , 0.03885137],
#        [0.60528625, 0.02536996, 0.99390689, 0.45825506, 0.70471312],
#        [0.02499643, 0.08661078, 0.32681686, 0.92036565, 0.12623697],
#        [0.54362341, 0.64303556, 0.35569865, 0.46962966, 0.75114741]])

# %%
first_array = np.array([[15, 20], [25, 30]])

# %%
second_array = np.array([[35, 40], [45, 50]])

# %%
first_array + second_array
# Out:
# array([[50, 60],
#        [70, 80]])

# %%
third_array = np.array([[10], [20]])

# %%
third_array.shape
# Out:
# (2, 1)

# %%
first_matrix = np.array([[5, 10, 20]])

# %%
second_matrix = np.array([[25, 30], [35, 40], [12, 15]])

# %%
first_matrix.shape
# Out:
# (1, 3)

# %%
second_matrix.shape
# Out:
# (3, 2)

# %%
result_matrix = first_matrix.dot(second_matrix)

# %%
result_matrix
# Out:
# array([[715, 850]])
